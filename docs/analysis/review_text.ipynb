# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from datetime import datetime
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import platform
import pickle as pkl

system = platform.system()

if system == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
else:
    # !apt-get -y install fonts-nanum
    # !fc-cache -fv
    # !rm ~/.cache/matplotlib -rf

    plt.rcParams['font.family'] = 'NanumBarunGothic'

# %%
df_rewview = pd.read_csv('../data/steam.tos_review.csv')

# %%
df_rewview
# Out:
#                           _id                               ishelpful  \
# 0    6640c769bb0e68e4b15e99d5              아직 아무도 이 평가가 유용하다고 하지 않음 0
# 1    6640c769bb0e68e4b15e99d6                     1명이 이 평가가 유용하다고 함 0
# 2    6640c769bb0e68e4b15e99d7              아직 아무도 이 평가가 유용하다고 하지 않음 0
# 3    6640c769bb0e68e4b15e99d8                     2명이 이 평가가 유용하다고 함 0
# 4    6640c769bb0e68e4b15e99d9  1명이 이 평가가 유용하다고 함\n1명이 이 평가가 재미있다고 함 0
# ..                        ...                                     ...
# 273  6640c788bb0e68e4b15e9ae6                     1명이 이 평가가 유용하다고 함 0
# 274  6640c788bb0e68e4b15e9ae7  7명이 이 평가가 유용하다고 함\n4명이 이 평가가 재미있다고 함 1
# 275  6640c788bb0e68e4b15e9ae8  5명이 이 평가가 유용하다고 함\n3명이 이 평가가 재미있다고 함 1
# 276  6640c788bb0e68e4b15e9ae9  3명이 이 평가가 유용하다고 함\n3명이 이 평가가 재미있다고 함 1
# 277  6640c788bb0e68e4b15e9aea  6명이 이 평가가 유용하다고 함\n2명이 이 평가가 재미있다고 함 0
#
#     isrecommend       playtime           date  \
# 0           비추천    기록상 201.3시간   2024년 5월 12일
# 1           비추천     기록상 36.3시간   2024년 5월 11일
# 2            추천     기록상 37.0시간    2024년 5월 9일
# 3           비추천    기록상 554.7시간    2024년 5월 5일
# 4           비추천      기록상 0.3시간   2024년 4월 27일
# ..          ...            ...            ...
# 273          추천  기록상 6,891.3시간  2022년 12월 27일
# 274          추천    기록상 126.6시간  2022년 12월 27일
# 275          추천  기록상 7,390.8시간  2022년 12월 27일
# 276          추천  기록상 1,682.3시간  2022년 12월 27일
# 277          추천    기록상 209.6시간  2022년 12월 26일
#
#                                           content_text           user
# 0    복귀 한달 차. 클래스 캐시로 뽑아서 해야하는거에 놀란다. 캐시클래스 없이 한다? ...     한국인의두통냥맞다개
# 1                              그냥 예전 8랭크 시절이 가장 재미있다.       clscnsgid
# 2                                                 gg.    Alice schach
# 3                                     그래픽 좋은 채팅 프로그램.   Free Hongkong
# 4                                                   ??     SIMPLENICK
# ..                                                 ...            ...
# 273                                          초갓갬 트우시.    dkssudgktody
# 274                               트우시 다시 부활함 아무튼 부활함.         Abaddon
# 275                                               :).          SeungA
# 276  ??? : TOS PC는 스팀에서 날아오를 뭔가를 준비하고 있습니다. 동생이 열일해...            토트라
# 277                                      평생겜 스팀과 고고혓.    AncientTroll
#
# [278 rows x 7 columns]

# %% [markdown]
# ## 결측치 / 이상치 처리

# %%
df_product = df_product.drop(columns='_id')

# %%
df_product = df_product.drop_duplicates()

# %%
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50874 entries, 0 to 50875
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   large_category_name  50874 non-null  object
#  1   small_category_name  50719 non-null  object
#  2   zzim                 50874 non-null  int64
#  3   product_name         50874 non-null  object
#  4   product_price        49240 non-null  float64
#  5   product_event_price  49113 non-null  float64
#  6   seller_name          50874 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
df_product.query('small_category_name.isna()')
# Out:
#       large_category_name small_category_name  zzim  \
# 28567                인테리어                 NaN  1258
# 28568                인테리어                 NaN   805
# 28569                인테리어                 NaN   663
# 28570                인테리어                 NaN   624
# 28571                인테리어                 NaN   328
# ...                   ...                 ...   ...
# 28717                인테리어                 NaN   439
# 28718                인테리어                 NaN   387
# 28719                인테리어                 NaN   357
# 28720                인테리어                 NaN   404
# 28721                인테리어                 NaN   332
#
#                          product_name  product_price  product_event_price  \
# 28567                     LED 별별 키즈방등       130000.0             128550.0
# 28568         인테리어 특이한 무선 예쁜 플라밍고 무드등        18800.0              18462.0
# 28569         퍽라이트 LED 무드등 매직램프 리모컨포함        17000.0              16680.0
# 28570     무선 리모컨 LED 무드등 장식장 조명3개 1세트        16800.0              16482.0
# 28571  레논 LED 빈티지 펜던트 인테리어 카페 유리조명 전등        77000.0              76080.0
# ...                               ...            ...                  ...
# 28717                Y자형 행거 옷걸이 9811Y        46900.0              46281.0
# 28718                 T자형 행거 옷걸이 0402        32900.0              32421.0
# 28719                          5단 실버랙        35900.0              35391.0
# 28720            LED 그로잉 무드등 인테리어 스탠드        26650.0              26233.0
# 28721                     라이팅플러그L1 모음        20900.0              20541.0
#
#        seller_name
# 28567        유캔라이팅
# 28568  리브하우스님의 스토어
# 28569        유캔라이팅
# 28570    건강연구소 스토어
# 28571  리브하우스님의 스토어
# ...            ...
# 28717         파인블루
# 28718         파인블루
# 28719         파인블루
# 28720         파인블루
# 28721         파인블루
#
# [155 rows x 7 columns]

# %%
df_product['small_category_name'] = df_product['small_category_name'].fillna('조명')

# %%
df_product.loc[df_product['product_event_price'].isna() & df_product['product_price'].isna(), 'product_price'] = '구독특가'

# %%
df_product.loc[df_product['product_event_price'].isna(), 'product_event_price'] = '할인없음'

# %%
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50874 entries, 0 to 50875
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   large_category_name  50874 non-null  object
#  1   small_category_name  50874 non-null  object
#  2   zzim                 50874 non-null  int64
#  3   product_name         50874 non-null  object
#  4   product_price        50874 non-null  object
#  5   product_event_price  50874 non-null  object
#  6   seller_name          50874 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# ## top 10

# %%
snsdraw = df_product.sort_values('zzim',ascending=False)[:300].value_counts('seller_name')[:10]

# %%
snsdraw.values.sum()
# Out:
# 154

# %%
snsdraw.index
# Out:
# Index(['유니엠님의 스토어', '위시드님의 스토어', '천연지기님의 스토어', '댕유마켓님의 스토어', '뷰에스피', '쑈킹디씨',
#        '차차실버', '트윈클링스타님의 스토어', '다모아아토즈님의 스토어', '올콘'],
#       dtype='object', name='seller_name')

# %%
plt.figure(figsize=(12, 6))

sns.barplot(data=snsdraw.to_frame(), x=snsdraw.index,y=snsdraw.values)

plt.title('찜 상위 300개 항목의 판매자 top 10')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 찜 top 50

# %%
df_zzimtop50 = df_product.sort_values('zzim',ascending=False)[:50]

# %%
df_zzimtop50.query('product_price != "구독특가"')['product_price'].mean()
# Out:
# 32712.962962962964

# %%
df_zzimtop50
# Out:
#       large_category_name small_category_name    zzim  \
# 1625                   식품                건강식품  235018
# 19264                생활용품                주방용품  210630
# 6947               디지털/가전                주방가전  209084
# 19265                생활용품                주방용품  199282
# 48527                액세서리             귀걸이/피어싱  147755
# 2628                   식품                건강식품  147755
# 41456               캠핑/레저                  캠핑  144842
# 41519               캠핑/레저                  캠핑  144610
# 2627                   식품                건강식품  143970
# 41581               캠핑/레저                  캠핑  143909
# 41490               캠핑/레저                  캠핑  142950
# 41548               캠핑/레저                  캠핑  142926
# 41491               캠핑/레저                  캠핑  142891
# 41543               캠핑/레저                  캠핑  142823
# 41550               캠핑/레저                  캠핑  142640
# 41544               캠핑/레저                  캠핑  142564
# 41823               캠핑/레저                  캠핑  142385
# 42520               캠핑/레저                  낚시  142385
# 19274                생활용품                주방용품  142167
# 41494               캠핑/레저                  캠핑  141982
# 41582               캠핑/레저                  캠핑  141838
# 7364               디지털/가전                생활가전  136795
# 41725               캠핑/레저                  캠핑  136178
# 42202               캠핑/레저                  등산  136178
# 19317                생활용품                주방용품  134826
# 21422                생활용품                청소용품  133846
# 19594                생활용품                주방용품  122547
# 7056               디지털/가전                주방가전  103726
# 22131                생활용품               생활필수품   94976
# 31237                액세서리                 목걸이   79884
# 47362                액세서리             귀걸이/피어싱   79884
# 19437                생활용품                주방용품   78715
# 35871               가방/잡화              지갑/클러치   71820
# 29981               유아동용품               놀이/학습   70654
# 6667               디지털/가전                주방가전   70310
# 22207                생활용품               생활필수품   69365
# 26908                인테리어             주방가구/데코   68790
# 20482                생활용품                주방용품   68790
# 2928                   식품                가공식품   68549
# 4829                   식품                차/커피   68549
# 26655                인테리어             주방가구/데코   68183
# 16086              Man 패션                  상의   65977
# 17419              Man 패션                 아우터   65977
# 15545             Lady 패션              스포츠/레저   63738
# 7367               디지털/가전                생활가전   61401
# 6131               디지털/가전                계절가전   60758
# 6318               디지털/가전                계절가전   60421
# 6317               디지털/가전                계절가전   59908
# 1914                   식품                건강식품   58812
# 15454             Lady 패션              원피스/세트   58281
#
#                                             product_name product_price  \
# 1625                          휴먼케어 프리미엄 루테인 500mg x 90캡슐          구독특가
# 19264                         [무료배송] 쉬젤 엘레강스 스퀘어도마(컷팅보드)          구독특가
# 6947                             [무료배송] 테팔 미니 프리토 튀김기 1L          구독특가
# 19265                            [무료배송] 알렌토 스카니아 도자기 홈세트          구독특가
# 48527                                       농협 침향공력환 60환          구독특가
# 2628                                        농협 침향공력환 60환          구독특가
# 41456               사계절 확장형 침낭 아웃도어 차박 캠핑 비박 텐트 커플 이불 침낭       33550.0
# 41519              접이식 캠핑 수레 다용도 시장 장바구니 쇼핑 핸드 카트 캐리어 웨건       22000.0
# 2627                               농협 천년산삼배양근 60ml X 60포          구독특가
# 41581       2m 3m 대형 피크닉 야외매트 캠핑 돗자리 매트 방수포 텐트 바닥 깔개 돗자리       11000.0
# 41490          700g 하계용 사계절 여름 침낭 아웃도어 차박 캠핑 비박 텐트 이불 침낭       23000.0
# 41548                감성캠핑 차박 노지캠핑 테이블 가벼운 휴대용 접이식 간이 테이블       26800.0
# 41491                     감성 캠핑 랜턴걸이 차박 카박 야외 스탠드 조명 거치대       12800.0
# 41543     감성 캠핑 삼각대 고리 삼발이 브라켓 더치오븐 야영 모닥불 화롯대 캠프파이어 삼각대       28000.0
# 41550             감성 캠핑 선반 소품 식기 걸이 차박 인디언 노지캠핑 우드 행거 행어       32000.0
# 41544             감성 캠핑 행어 소품 식기 걸이 차박 카박 인디언 노지캠핑 우드 행거       28000.0
# 41823              휴대용 접이식 등받이 낚시의자 아웃도어 낚시대 버클 고정 캠핑 의자       32000.0
# 42520              휴대용 접이식 등받이 낚시의자 아웃도어 낚시대 버클 고정 캠핑 의자       32000.0
# 19274       아웃도어 감성 캠핑 PE 접이식 물통 설거지 물탱크 캠핑물통 식수통 5L 10L        5800.0
# 41494              감성 노지 캠핑 랜턴걸이 차박 카박 야외 삼각대 스탠드 조명 거치대       29800.0
# 41582             소품 식기 걸이 차박 카박 인디언 노지캠핑 우드 행거 감성 캠핑 행어       36000.0
# 7364                     한샘 스톰건 무선청소기 250W STORM GUN V12          구독특가
# 41725                        버팔로 체로키 데이팩 배낭 20L (Yellow)          구독특가
# 42202                        버팔로 체로키 데이팩 배낭 20L (Yellow)          구독특가
# 19317                            [무료배송] 쉬젤 엘레강스 키친툴 7종세트          구독특가
# 21422                    [루첸] 클라인 빗자루 무선 물걸레청소기 MTW-2000          구독특가
# 19594                                   바이마르 히든쉐프 5종냄비세트          구독특가
# 7056                                     [무료배송] 알렌토 미니밥솥          구독특가
# 22131                          리앤쿡 워터플로셔 휴대용 구강세정기 LC600          구독특가
# 31237                                                기프트       10000.0
# 47362                                                기프트       10000.0
# 19437                                             한땀 뚝배기       18000.0
# 35871                                            맘새김 반지갑       15900.0
# 29981                              [일본정품] 야도란 판쵸 피카츄 신상품      170000.0
# 6667   [웅진렌탈] 직수형 조약돌 정수기 DCH-AUS100/제휴카드할인 2만원/의무기간3...       33900.0
# 22207                         우리가족 건강지킴이 친환경 살균소독수 호클러셋트          구독특가
# 26908                        헤스티앙 통3중(3Ply)스텐레스 냄비 4종 세트          구독특가
# 20482                        헤스티앙 통3중(3Ply)스텐레스 냄비 4종 세트          구독특가
# 2928   천연곡물팩,마사지 재료/누룩,살구씨,율무,노니,오트밀,미강,다시마,율피,비타민c,히...        2600.0
# 4829   천연곡물팩,마사지 재료/누룩,살구씨,율무,노니,오트밀,미강,다시마,율피,비타민c,히...        2600.0
# 26655          DF감성 화이트 라운드 예쁜거실 테이블 식탁 카페, 업소용테이블 4인 6인      180000.0
# 16086                           커플남자패딩조끼베스트 커플조끼패딩(2075)       21300.0
# 17419                           커플남자패딩조끼베스트 커플조끼패딩(2075)       21300.0
# 15545                    [오늘출발]5부 레깅스 바이커쇼츠 애슬레저룩 4color       12900.0
# 7367                                 보만 스탠드 스팀다리미 DB8230          구독특가
# 6131                        길리 서큘레이터 공기순환 선풍기 ING-1000CW          구독특가
# 6318                        스위스밀리터리 14인치 5엽 선풍기 SMF-1400          구독특가
# 6317                        지앤씨 리모컨 3단 타워형 선풍기 GE-EF3696          구독특가
# 1914                                        상아 홍삼정 데일리타임          구독특가
# 15454                            체크 허리 벨트 V 미디 원피스 F5663       32000.0
#
#       product_event_price      seller_name
# 1625                 할인없음             신라상점
# 19264                할인없음     코지어플렌티님의 스토어
# 6947                 할인없음     코지어플렌티님의 스토어
# 19265                할인없음     코지어플렌티님의 스토어
# 48527                할인없음             쑈킹디씨
# 2628                 할인없음             쑈킹디씨
# 41456             33064.0       댕유마켓님의 스토어
# 41519             21630.0       댕유마켓님의 스토어
# 2627                 할인없음             쑈킹디씨
# 41581             10740.0       댕유마켓님의 스토어
# 41490             22620.0       댕유마켓님의 스토어
# 41548             26382.0       댕유마켓님의 스토어
# 41491             12522.0       댕유마켓님의 스토어
# 41543             27570.0       댕유마켓님의 스토어
# 41550             31530.0       댕유마켓님의 스토어
# 41544             27570.0       댕유마켓님의 스토어
# 41823             31530.0       댕유마켓님의 스토어
# 42520             31530.0       댕유마켓님의 스토어
# 19274              5592.0       댕유마켓님의 스토어
# 41494             29352.0       댕유마켓님의 스토어
# 41582             35490.0       댕유마켓님의 스토어
# 7364                 할인없음  Tefillah 님의 스토어
# 41725                할인없음        싸다샵님의 스토어
# 42202                할인없음        싸다샵님의 스토어
# 19317                할인없음     코지어플렌티님의 스토어
# 21422                할인없음    SSADAGU님의 스토어
# 19594                할인없음  Tefillah 님의 스토어
# 7056                 할인없음     코지어플렌티님의 스토어
# 22131                할인없음  Tefillah 님의 스토어
# 31237              9750.0     ㄱ디비디엠♡님의 스토어
# 47362              9750.0     ㄱ디비디엠♡님의 스토어
# 19437             17670.0             여우자기
# 35871             15591.0             써니마켓
# 29981            168150.0            포켓몬센터
# 6667              33411.0              렌탈인
# 22207                할인없음       공구마켓님의 스토어
# 26908                할인없음     쌓여라지식아님의 스토어
# 20482                할인없음     쌓여라지식아님의 스토어
# 2928               2424.0             릴리스타
# 4829               2424.0             릴리스타
# 26655            178050.0      DFfurniture
# 16086             20937.0       댕유마켓님의 스토어
# 17419             20937.0       댕유마켓님의 스토어
# 15545             12621.0        티엘유님의 스토어
# 7367                 할인없음    SSADAGU님의 스토어
# 6131                 할인없음     트윈클링스타님의 스토어
# 6318                 할인없음     트윈클링스타님의 스토어
# 6317                 할인없음     트윈클링스타님의 스토어
# 1914                 할인없음            핫딜1번지
# 15454             31530.0      오늘도 예쁘게 엠투걸

# %%
plt.figure(figsize=(10, 6))

zzim_order = df_zzimtop50.value_counts('large_category_name').index

sns.countplot(data=df_zzimtop50, x='large_category_name', order=zzim_order, palette='pastel')

plt.title('zzim top 50 카테고리')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))

zzim_order = df_zzimtop50.value_counts('small_category_name').index

sns.countplot(data=df_zzimtop50, x='small_category_name', order=zzim_order, palette='pastel')

plt.title('zzim top 50 세부 카테고리')
plt.xticks(rotation=45)
plt.show()
